# %% [markdown]
# # Assignment 3: Hello Vectors
#
# Welcome to this week's programming assignment on exploring word vectors.
# In natural language processing, we represent each word as a vector consisting of numbers.
# The vector encodes the meaning of the word. These numbers (or weights) for each word are learned using various machine
# learning models, which we will explore in more detail later in this specialization. Rather than make you code the
# machine learning models from scratch, we will show you how to use them. In the real world, you can always load the
# trained word vectors, and you will almost never have to train them from scratch. In this assignment, you will:
#
# - Predict analogies between words.
# - Use PCA to reduce the dimensionality of the word embeddings and plot them in two dimensions.
# - Compare word embeddings by using a similarity measure (the cosine similarity).
# - Understand how these vector space models work.
#
#
#
# ## 1.0 Predict the Countries from Capitals
#
# In the lectures, we have illustrated the word analogies
# by finding the capital of a country from the country.
# We have changed the problem a bit in this part of the assignment. You are asked to predict the **countries**
# that corresponds to some **capitals**.
# You are playing trivia against some second grader who just took their geography test and knows all the capitals by heart.
# Thanks to NLP, you will be able to answer the questions properly. In other words, you will write a program that can give
# you the country by its capital. That way you are pretty sure you will win the trivia game. We will start by exploring the data set.
#
# <img src = 'map.jpg' width="width" height="height" style="width:467px;height:300px;"/>
#
# ###  1.1 Importing the data
#
# As usual, you start by importing some essential Python libraries and then load the dataset.
# The dataset will be loaded as a [Pandas DataFrame](https://pandas.pydata.org/pandas-docs/stable/getting_started/dsintro.html),
# which is very a common method in data science.
# This may take a few minutes because of the large size of the data.

# %%
# Run this cell to import packages.
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math

from utils import get_vectors

# %%
data = pd.read_csv('capitals.txt', delimiter=' ')
data.columns = ['city1', 'country1', 'city2', 'country2']

# print first five elements in the DataFrame
data.head(5)
# Out:
#     city1 country1    city2     country2
# 0  Athens   Greece  Bangkok     Thailand
# 1  Athens   Greece  Beijing        China
# 2  Athens   Greece   Berlin      Germany
# 3  Athens   Greece     Bern  Switzerland
# 4  Athens   Greece    Cairo        Egypt

# %% [markdown]
# ***
#
# ### To Run This Code On Your Own Machine:
# Note that because the original google news word embedding dataset is about 3.64 gigabytes,
# the workspace is not able to handle the full file set.  So we've downloaded the full dataset,
# extracted a sample of the words that we're going to analyze in this assignment, and saved
# it in a pickle file called `word_embeddings_capitals.p`
#
# If you want to download the full dataset on your own and choose your own set of word embeddings,
# please see the instructions and some helper code.
#
# - Download the dataset from this [page](https://code.google.com/archive/p/word2vec/).
# - Search in the page for 'GoogleNews-vectors-negative300.bin.gz' and click the link to download.

# %% [markdown]
# Copy-paste the code below and run it on your local machine after downloading
# the dataset to the same directory as the notebook.
#
# ```python
# import nltk
# from gensim.models import KeyedVectors
#
#
# embeddings = KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary = True)
# f = open('capitals.txt', 'r').read()
# set_words = set(nltk.word_tokenize(f))
# select_words = words = ['king', 'queen', 'oil', 'gas', 'happy', 'sad', 'city', 'town', 'village', 'country', 'continent', 'petroleum', 'joyful']
# for w in select_words:
#     set_words.add(w)
#
# def get_word_embeddings(embeddings):
#
#     word_embeddings = {}
#     for word in embeddings.vocab:
#         if word in set_words:
#             word_embeddings[word] = embeddings[word]
#     return word_embeddings
#
#
# # Testing your function
# word_embeddings = get_word_embeddings(embeddings)
# print(len(word_embeddings))
# pickle.dump( word_embeddings, open( "word_embeddings_subset.p", "wb" ) )
# ```
#
# ***

# %% [markdown]
# Now we will load the word embeddings as a [Python dictionary](https://docs.python.org/3/tutorial/datastructures.html#dictionaries).
# As stated, these have already been obtained through a machine learning algorithm.

# %%
word_embeddings = pickle.load(open("word_embeddings_subset.p", "rb"))
print(len(word_embeddings)) # there should be 243 words that will be used in this assignment
print(type(word_embeddings))
# Out:
# 243
# <class 'dict'>

# %% [markdown]
# Each of the word embedding is a 300-dimensional vector.

# %%
print("dimension: {}".format(word_embeddings['Spain'].shape[0]))
# Out:
# dimension: 300

# %% [markdown]
# ### Predict relationships among words
#
# Now you will write a function that will use the word embeddings to predict relationships among words.
# * The function will take as input three words.
# * The first two are related to each other.
# * It will predict a 4th word which is related to the third word in a similar manner as the two first words are related to each other.
# * As an example, "Athens is to Greece as Bangkok is to ______"?
# * You will write a program that is capable of finding the fourth word.
# * We will give you a hint to show you how to compute this.
#
# A similar analogy would be the following:
#
# <img src = 'vectors.jpg' width="width" height="height" style="width:467px;height:200px;"/>
#
# You will implement a function that can tell you the capital of a country.
# You should use the same methodology shown in the figure above. To do this,
# compute you'll first compute cosine similarity metric or the Euclidean distance.

# %% [markdown]
# ### 1.2 Cosine Similarity
#
# The cosine similarity function is:
#
# $$\cos (\theta)=\frac{\mathbf{A} \cdot \mathbf{B}}{\|\mathbf{A}\|\|\mathbf{B}\|}=\frac{\sum_{i=1}^{n} A_{i} B_{i}}{\sqrt{\sum_{i=1}^{n} A_{i}^{2}} \sqrt{\sum_{i=1}^{n} B_{i}^{2}}}\tag{1}$$
#
# $A$ and $B$ represent the word vectors and $A_i$ or $B_i$ represent index i of that vector.
# & Note that if A and B are identical, you will get $cos(\theta) = 1$.
# * Otherwise, if they are the total opposite, meaning, $A= -B$, then you would get $cos(\theta) = -1$.
# * If you get $cos(\theta) =0$, that means that they are orthogonal (or perpendicular).
# * Numbers between 0 and 1 indicate a similarity score.
# * Numbers between -1-0 indicate a dissimilarity score.
#
# **Instructions**: Implement a function that takes in two word vectors and computes the cosine distance.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Python's<a href="https://docs.scipy.org/doc/numpy/reference/" > NumPy library </a> adds support for linear algebra operations (e.g., dot product, vector norm ...).</li>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.dot.html" > numpy.dot </a>.</li>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.norm.html">numpy.linalg.norm </a>.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def cosine_similarity(A, B):
    '''
    Input:
        A: a numpy array which corresponds to a word vector
        B: A numpy array which corresponds to a word vector
    Output:
        cos: numerical number representing the cosine similarity between A and B.
    '''

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    #print(f'A type: {type(A[0])}')
    #print(f'B type: {type(B[0])}')

    dot = np.dot(A, B)
    norma = math.sqrt(np.dot(A, A)) #np.linalg.norm(A)
    normb = math.sqrt(np.dot(B, B)) #np.linalg.norm(B)
    cos = dot/(norma * normb)

    ### END CODE HERE ###
    return cos

# %%
# feel free to try different words
king = word_embeddings['king']
queen = word_embeddings['queen']
cosine_similarity(king, queen)
# Out:
# A type: <class 'numpy.float32'>
# B type: <class 'numpy.float32'>
# 0.6510956610004666

# %% [markdown]
# **Expected Output**:
#
# $\approx$ 0.6510956

# %% [markdown]
# ### 1.3 Euclidean distance
#
# You will now implement a function that computes the similarity between two vectors using the Euclidean distance.
# Euclidean distance is defined as:
#
# $$ \begin{aligned} d(\mathbf{A}, \mathbf{B})=d(\mathbf{B}, \mathbf{A}) &=\sqrt{\left(A_{1}-B_{1}\right)^{2}+\left(A_{2}-B_{2}\right)^{2}+\cdots+\left(A_{n}-B_{n}\right)^{2}} \\ &=\sqrt{\sum_{i=1}^{n}\left(A_{i}-B_{i}\right)^{2}} \end{aligned}$$
#
# * $n$ is the number of elements in the vector
# * $A$ and $B$ are the corresponding word vectors.
# * The more similar the words, the more likely the Euclidean distance will be close to 0.
#
# **Instructions**: Write a function that computes the Euclidean distance between two vectors.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.norm.html" > numpy.linalg.norm </a>.</li>
# </ul>
# </p>

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def euclidean(A, B):
    """
    Input:
        A: a numpy array which corresponds to a word vector
        B: A numpy array which corresponds to a word vector
    Output:
        d: numerical number representing the Euclidean distance between A and B.
    """

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # euclidean distance

    diff = A - B
    d = np.linalg.norm(diff) # math.sqrt(np.dot(diff, diff))

    ### END CODE HERE ###

    return d

# %%
# Test your function
euclidean(king, queen)
# Out:
# 2.4796925

# %% [markdown]
# **Expected Output:**
#
# 2.4796925

# %% [markdown]
# ### 1.4 Finding the country of each capital
#
# Now, you  will use the previous functions to compute similarities between vectors,
# and use these to find the capital cities of countries. You will write a function that
# takes in three words, and the embeddings dictionary. Your task is to find the
# capital cities. For example, given the following words:
#
# - 1: Athens 2: Greece 3: Baghdad,
#
# your task is to predict the country 4: Iraq.
#
# **Instructions**:
#
# 1. To predict the capital you might want to look at the *King - Man + Woman = Queen* example above, and implement that scheme into a mathematical function, using the word embeddings and a similarity function.
#
# 2. Iterate over the embeddings dictionary and compute the cosine similarity score between your vector and the current word embedding.
#
# 3. You should add a check to make sure that the word you return is not any of the words that you fed into your function. Return the one with the highest score.

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_country(city1, country1, city2, embeddings):
    """
    Input:
        city1: a string (the capital city of country1)
        country1: a string (the country of capital1)
        city2: a string (the capital city of country2)
        embeddings: a dictionary where the keys are words and values are their embeddings
    Output:
        countries: a dictionary with the most likely country and its similarity score
    """
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # store the city1, country 1, and city 2 in a set called group
    group = set((city1, country1, city2))

    # get embeddings of city 1
    city1_emb = embeddings[city1]

    # get embedding of country 1
    country1_emb = embeddings[country1]

    # get embedding of city 2
    city2_emb =  embeddings[city2]

    # get embedding of country 2 (it's a combination of the embeddings of country 1, city 1 and city 2)
    # Remember: King - Man + Woman = Queen
    vec = country1_emb - city1_emb + city2_emb # projected country 2 embedding based on vector difference

    # Initialize the similarity to -1 (it will be replaced by a similarities that are closer to +1)
    similarity = -1

    # initialize country to an empty string
    country = ''

    # loop through all words in the embeddings dictionary
    for word in embeddings.keys():

        # first check that the word is not already in the 'group'
        if word not in group:

            # get the word embedding
            word_emb = embeddings[word]

            # calculate cosine similarity between embedding of country 2 and the word in the embeddings dictionary
            cur_similarity = cosine_similarity(vec, word_emb)

            # if the cosine similarity is more similar than the previously best similarity...
            if cur_similarity > similarity:

                # update the similarity to the new, better similarity
                similarity = cur_similarity

                # store the country as a tuple, which contains the word and the similarity
                country = (word, similarity)

    ### END CODE HERE ###

    return country

# %%
# Testing your function, note to make it more robust you can return the 5 most similar words.
get_country('Athens', 'Greece', 'Cairo', word_embeddings)
# Out:
# ('Egypt', 0.7626821508358924)

# %% [markdown]
# **Expected Output:**
#
# ('Egypt', 0.7626821)

# %% [markdown]
# ### 1.5 Model Accuracy
#
# Now you will test your new function on the dataset and check the accuracy of the model:
#
# $$\text{Accuracy}=\frac{\text{Correct # of predictions}}{\text{Total # of predictions}}$$
#
# **Instructions**: Write a program that can compute the accuracy on the dataset provided for you. You have to iterate over every row to get the corresponding words and feed them into you `get_country` function above.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iterrows.html" > pandas.DataFrame.iterrows </a>.</li>
# </ul>
# </p>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_accuracy(word_embeddings, data):
    '''
    Input:
        word_embeddings: a dictionary where the key is a word and the value is its embedding
        data: a pandas dataframe containing all the country and capital city pairs
    
    Output:
        accuracy: the accuracy of the model
    '''

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # initialize num correct to zero
    num_correct = 0

    # loop through the rows of the dataframe
    for i, row in data.iterrows():
        # print(row)  

        # get city1
        city1 = row.city1

        # get country1
        country1 = row.country1

        # get city2
        city2 =  row.city2   

        # get country2
        country2 = row.country2

        # use get_country to find the predicted country2
        predicted_country2, _ = get_country(city1, country1, city2, word_embeddings)
        
        # print(f'ci1: {city1}, co1: {country1}, ci2: {city2}, co2: {country2} => pred_co2: {predicted_country2}')

        # if the predicted country2 is the same as the actual country2...
        if predicted_country2 == country2:
            # increment the number of correct by 1
            num_correct += 1

    # get the number of rows in the data dataframe (length of dataframe)
    m = len(data)

    # calculate the accuracy by dividing the number correct by m
    accuracy = num_correct/m

    ### END CODE HERE ###
    return accuracy

# %% [markdown]
# **NOTE: The cell below takes about 30 SECONDS to run.**

# %%
accuracy = get_accuracy(word_embeddings, data)
print(f"Accuracy is {accuracy:.2f}")
# Out:
# ci1: Athens, co1: Greece, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Athens, co1: Greece, ci2: Beijing, co2: China => pred_co2: China
# ci1: Athens, co1: Greece, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Athens, co1: Greece, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Athens, co1: Greece, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Athens, co1: Greece, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Athens, co1: Greece, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Athens, co1: Greece, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Athens, co1: Greece, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Athens, co1: Greece, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Athens, co1: Greece, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Athens, co1: Greece, ci2: London, co2: England => pred_co2: Portugal
# ci1: Athens, co1: Greece, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Athens, co1: Greece, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Athens, co1: Greece, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Athens, co1: Greece, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Athens, co1: Greece, ci2: Paris, co2: France => pred_co2: France
# ci1: Athens, co1: Greece, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Athens, co1: Greece, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Athens, co1: Greece, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Athens, co1: Greece, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Baghdad, co1: Iraq, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Baghdad, co1: Iraq, ci2: Beijing, co2: China => pred_co2: China
# ci1: Baghdad, co1: Iraq, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Baghdad, co1: Iraq, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Baghdad, co1: Iraq, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Baghdad, co1: Iraq, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Baghdad, co1: Iraq, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Baghdad, co1: Iraq, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Baghdad, co1: Iraq, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Baghdad, co1: Iraq, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Baghdad, co1: Iraq, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Baghdad, co1: Iraq, ci2: London, co2: England => pred_co2: England
# ci1: Baghdad, co1: Iraq, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Baghdad, co1: Iraq, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Baghdad, co1: Iraq, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Baghdad, co1: Iraq, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Baghdad, co1: Iraq, ci2: Paris, co2: France => pred_co2: France
# ci1: Baghdad, co1: Iraq, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Baghdad, co1: Iraq, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Baghdad, co1: Iraq, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Baghdad, co1: Iraq, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Baghdad, co1: Iraq, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Bangkok, co1: Thailand, ci2: Beijing, co2: China => pred_co2: China
# ci1: Bangkok, co1: Thailand, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Bangkok, co1: Thailand, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Bangkok, co1: Thailand, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Bangkok, co1: Thailand, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Bangkok, co1: Thailand, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Bangkok, co1: Thailand, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Bangkok, co1: Thailand, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Bangkok, co1: Thailand, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Bangkok, co1: Thailand, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Bangkok, co1: Thailand, ci2: London, co2: England => pred_co2: England
# ci1: Bangkok, co1: Thailand, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Bangkok, co1: Thailand, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Bangkok, co1: Thailand, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Bangkok, co1: Thailand, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Bangkok, co1: Thailand, ci2: Paris, co2: France => pred_co2: France
# ci1: Bangkok, co1: Thailand, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Bangkok, co1: Thailand, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Bangkok, co1: Thailand, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Bangkok, co1: Thailand, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Bangkok, co1: Thailand, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Bangkok, co1: Thailand, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Beijing, co1: China, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Beijing, co1: China, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Beijing, co1: China, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Beijing, co1: China, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Beijing, co1: China, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Beijing, co1: China, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Beijing, co1: China, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Beijing, co1: China, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Beijing, co1: China, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Beijing, co1: China, ci2: London, co2: England => pred_co2: England
# ci1: Beijing, co1: China, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Beijing, co1: China, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Beijing, co1: China, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Beijing, co1: China, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Beijing, co1: China, ci2: Paris, co2: France => pred_co2: France
# ci1: Beijing, co1: China, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Beijing, co1: China, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Beijing, co1: China, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Beijing, co1: China, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Beijing, co1: China, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Beijing, co1: China, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Beijing, co1: China, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Berlin, co1: Germany, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Berlin, co1: Germany, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Berlin, co1: Germany, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Berlin, co1: Germany, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Berlin, co1: Germany, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Berlin, co1: Germany, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Berlin, co1: Germany, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Berlin, co1: Germany, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Berlin, co1: Germany, ci2: London, co2: England => pred_co2: Australia
# ci1: Berlin, co1: Germany, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Berlin, co1: Germany, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Berlin, co1: Germany, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Berlin, co1: Germany, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Berlin, co1: Germany, ci2: Paris, co2: France => pred_co2: France
# ci1: Berlin, co1: Germany, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Berlin, co1: Germany, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Berlin, co1: Germany, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Berlin, co1: Germany, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Berlin, co1: Germany, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Berlin, co1: Germany, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Berlin, co1: Germany, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Berlin, co1: Germany, ci2: Beijing, co2: China => pred_co2: China
# ci1: Bern, co1: Switzerland, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Bern, co1: Switzerland, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Bern, co1: Switzerland, ci2: Hanoi, co2: Vietnam => pred_co2: Laos
# ci1: Bern, co1: Switzerland, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Bern, co1: Switzerland, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Bern, co1: Switzerland, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Bern, co1: Switzerland, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Bern, co1: Switzerland, ci2: London, co2: England => pred_co2: Australia
# ci1: Bern, co1: Switzerland, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Bern, co1: Switzerland, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Bern, co1: Switzerland, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Bern, co1: Switzerland, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Bern, co1: Switzerland, ci2: Paris, co2: France => pred_co2: France
# ci1: Bern, co1: Switzerland, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Bern, co1: Switzerland, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Bern, co1: Switzerland, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Bern, co1: Switzerland, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Bern, co1: Switzerland, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Bern, co1: Switzerland, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Bern, co1: Switzerland, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Bern, co1: Switzerland, ci2: Beijing, co2: China => pred_co2: China
# ci1: Bern, co1: Switzerland, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Cairo, co1: Egypt, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Cairo, co1: Egypt, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Cairo, co1: Egypt, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Cairo, co1: Egypt, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Cairo, co1: Egypt, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Cairo, co1: Egypt, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Cairo, co1: Egypt, ci2: London, co2: England => pred_co2: England
# ci1: Cairo, co1: Egypt, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Cairo, co1: Egypt, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Cairo, co1: Egypt, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Cairo, co1: Egypt, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Cairo, co1: Egypt, ci2: Paris, co2: France => pred_co2: France
# ci1: Cairo, co1: Egypt, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Cairo, co1: Egypt, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Cairo, co1: Egypt, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Cairo, co1: Egypt, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Cairo, co1: Egypt, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Cairo, co1: Egypt, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Cairo, co1: Egypt, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Cairo, co1: Egypt, ci2: Beijing, co2: China => pred_co2: China
# ci1: Cairo, co1: Egypt, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Cairo, co1: Egypt, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Canberra, co1: Australia, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Canberra, co1: Australia, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Canberra, co1: Australia, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Canberra, co1: Australia, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Canberra, co1: Australia, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Canberra, co1: Australia, ci2: London, co2: England => pred_co2: England
# ci1: Canberra, co1: Australia, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Canberra, co1: Australia, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Canberra, co1: Australia, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Canberra, co1: Australia, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Canberra, co1: Australia, ci2: Paris, co2: France => pred_co2: France
# ci1: Canberra, co1: Australia, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Canberra, co1: Australia, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Canberra, co1: Australia, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Canberra, co1: Australia, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Canberra, co1: Australia, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Canberra, co1: Australia, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Canberra, co1: Australia, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Canberra, co1: Australia, ci2: Beijing, co2: China => pred_co2: China
# ci1: Canberra, co1: Australia, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Canberra, co1: Australia, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Canberra, co1: Australia, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Hanoi, co1: Vietnam, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Hanoi, co1: Vietnam, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Hanoi, co1: Vietnam, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Hanoi, co1: Vietnam, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Hanoi, co1: Vietnam, ci2: London, co2: England => pred_co2: England
# ci1: Hanoi, co1: Vietnam, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Hanoi, co1: Vietnam, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Hanoi, co1: Vietnam, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Hanoi, co1: Vietnam, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Hanoi, co1: Vietnam, ci2: Paris, co2: France => pred_co2: France
# ci1: Hanoi, co1: Vietnam, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Hanoi, co1: Vietnam, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Hanoi, co1: Vietnam, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Hanoi, co1: Vietnam, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Hanoi, co1: Vietnam, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Hanoi, co1: Vietnam, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Hanoi, co1: Vietnam, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Hanoi, co1: Vietnam, ci2: Beijing, co2: China => pred_co2: China
# ci1: Hanoi, co1: Vietnam, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Hanoi, co1: Vietnam, ci2: Bern, co2: Switzerland => pred_co2: Lebanon
# ci1: Hanoi, co1: Vietnam, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Hanoi, co1: Vietnam, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Havana, co1: Cuba, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Havana, co1: Cuba, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Havana, co1: Cuba, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Havana, co1: Cuba, ci2: London, co2: England => pred_co2: England
# ci1: Havana, co1: Cuba, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Havana, co1: Cuba, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Havana, co1: Cuba, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Havana, co1: Cuba, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Havana, co1: Cuba, ci2: Paris, co2: France => pred_co2: France
# ci1: Havana, co1: Cuba, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Havana, co1: Cuba, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Havana, co1: Cuba, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Havana, co1: Cuba, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Havana, co1: Cuba, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Havana, co1: Cuba, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Havana, co1: Cuba, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Havana, co1: Cuba, ci2: Beijing, co2: China => pred_co2: China
# ci1: Havana, co1: Cuba, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Havana, co1: Cuba, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Havana, co1: Cuba, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Havana, co1: Cuba, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Havana, co1: Cuba, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Helsinki, co1: Finland, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Helsinki, co1: Finland, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Helsinki, co1: Finland, ci2: London, co2: England => pred_co2: England
# ci1: Helsinki, co1: Finland, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Helsinki, co1: Finland, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Helsinki, co1: Finland, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Helsinki, co1: Finland, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Helsinki, co1: Finland, ci2: Paris, co2: France => pred_co2: France
# ci1: Helsinki, co1: Finland, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Helsinki, co1: Finland, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Helsinki, co1: Finland, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Helsinki, co1: Finland, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Helsinki, co1: Finland, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Helsinki, co1: Finland, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Helsinki, co1: Finland, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Helsinki, co1: Finland, ci2: Beijing, co2: China => pred_co2: China
# ci1: Helsinki, co1: Finland, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Helsinki, co1: Finland, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Helsinki, co1: Finland, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Helsinki, co1: Finland, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Helsinki, co1: Finland, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Helsinki, co1: Finland, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Islamabad, co1: Pakistan, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Islamabad, co1: Pakistan, ci2: London, co2: England => pred_co2: England
# ci1: Islamabad, co1: Pakistan, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Islamabad, co1: Pakistan, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Islamabad, co1: Pakistan, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Islamabad, co1: Pakistan, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Islamabad, co1: Pakistan, ci2: Paris, co2: France => pred_co2: France
# ci1: Islamabad, co1: Pakistan, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Islamabad, co1: Pakistan, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Islamabad, co1: Pakistan, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Islamabad, co1: Pakistan, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Islamabad, co1: Pakistan, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Islamabad, co1: Pakistan, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Islamabad, co1: Pakistan, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Islamabad, co1: Pakistan, ci2: Beijing, co2: China => pred_co2: China
# ci1: Islamabad, co1: Pakistan, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Islamabad, co1: Pakistan, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Islamabad, co1: Pakistan, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Islamabad, co1: Pakistan, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Islamabad, co1: Pakistan, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Islamabad, co1: Pakistan, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Islamabad, co1: Pakistan, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Kabul, co1: Afghanistan, ci2: London, co2: England => pred_co2: England
# ci1: Kabul, co1: Afghanistan, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Kabul, co1: Afghanistan, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Kabul, co1: Afghanistan, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Kabul, co1: Afghanistan, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Kabul, co1: Afghanistan, ci2: Paris, co2: France => pred_co2: France
# ci1: Kabul, co1: Afghanistan, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Kabul, co1: Afghanistan, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Kabul, co1: Afghanistan, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Kabul, co1: Afghanistan, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Kabul, co1: Afghanistan, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Kabul, co1: Afghanistan, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Kabul, co1: Afghanistan, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Kabul, co1: Afghanistan, ci2: Beijing, co2: China => pred_co2: China
# ci1: Kabul, co1: Afghanistan, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Kabul, co1: Afghanistan, ci2: Bern, co2: Switzerland => pred_co2: Lebanon
# ci1: Kabul, co1: Afghanistan, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Kabul, co1: Afghanistan, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Kabul, co1: Afghanistan, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Kabul, co1: Afghanistan, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Kabul, co1: Afghanistan, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Kabul, co1: Afghanistan, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: London, co1: England, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: London, co1: England, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: London, co1: England, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: London, co1: England, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: London, co1: England, ci2: Paris, co2: France => pred_co2: France
# ci1: London, co1: England, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: London, co1: England, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: London, co1: England, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: London, co1: England, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: London, co1: England, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: London, co1: England, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: London, co1: England, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: London, co1: England, ci2: Beijing, co2: China => pred_co2: China
# ci1: London, co1: England, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: London, co1: England, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: London, co1: England, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: London, co1: England, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: London, co1: England, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: London, co1: England, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: London, co1: England, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: London, co1: England, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: London, co1: England, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Madrid, co1: Spain, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Madrid, co1: Spain, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Madrid, co1: Spain, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Madrid, co1: Spain, ci2: Paris, co2: France => pred_co2: France
# ci1: Madrid, co1: Spain, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Madrid, co1: Spain, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Madrid, co1: Spain, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Madrid, co1: Spain, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Madrid, co1: Spain, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Madrid, co1: Spain, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Madrid, co1: Spain, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Madrid, co1: Spain, ci2: Beijing, co2: China => pred_co2: China
# ci1: Madrid, co1: Spain, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Madrid, co1: Spain, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Madrid, co1: Spain, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Madrid, co1: Spain, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Madrid, co1: Spain, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Madrid, co1: Spain, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Madrid, co1: Spain, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Madrid, co1: Spain, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Madrid, co1: Spain, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Madrid, co1: Spain, ci2: London, co2: England => pred_co2: England
# ci1: Moscow, co1: Russia, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Moscow, co1: Russia, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Moscow, co1: Russia, ci2: Paris, co2: France => pred_co2: France
# ci1: Moscow, co1: Russia, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Moscow, co1: Russia, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Moscow, co1: Russia, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Moscow, co1: Russia, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Moscow, co1: Russia, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Moscow, co1: Russia, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Moscow, co1: Russia, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Moscow, co1: Russia, ci2: Beijing, co2: China => pred_co2: China
# ci1: Moscow, co1: Russia, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Moscow, co1: Russia, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Moscow, co1: Russia, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Moscow, co1: Russia, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Moscow, co1: Russia, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Moscow, co1: Russia, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Moscow, co1: Russia, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Moscow, co1: Russia, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Moscow, co1: Russia, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Moscow, co1: Russia, ci2: London, co2: England => pred_co2: England
# ci1: Moscow, co1: Russia, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Oslo, co1: Norway, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Oslo, co1: Norway, ci2: Paris, co2: France => pred_co2: France
# ci1: Oslo, co1: Norway, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Oslo, co1: Norway, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Oslo, co1: Norway, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Oslo, co1: Norway, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Oslo, co1: Norway, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Oslo, co1: Norway, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Oslo, co1: Norway, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Oslo, co1: Norway, ci2: Beijing, co2: China => pred_co2: China
# ci1: Oslo, co1: Norway, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Oslo, co1: Norway, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Oslo, co1: Norway, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Oslo, co1: Norway, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Oslo, co1: Norway, ci2: Hanoi, co2: Vietnam => pred_co2: Laos
# ci1: Oslo, co1: Norway, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Oslo, co1: Norway, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Oslo, co1: Norway, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Oslo, co1: Norway, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Oslo, co1: Norway, ci2: London, co2: England => pred_co2: England
# ci1: Oslo, co1: Norway, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Oslo, co1: Norway, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Ottawa, co1: Canada, ci2: Paris, co2: France => pred_co2: France
# ci1: Ottawa, co1: Canada, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Ottawa, co1: Canada, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Ottawa, co1: Canada, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Ottawa, co1: Canada, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Ottawa, co1: Canada, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Ottawa, co1: Canada, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Ottawa, co1: Canada, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Ottawa, co1: Canada, ci2: Beijing, co2: China => pred_co2: China
# ci1: Ottawa, co1: Canada, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Ottawa, co1: Canada, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Ottawa, co1: Canada, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Ottawa, co1: Canada, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Ottawa, co1: Canada, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Ottawa, co1: Canada, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Ottawa, co1: Canada, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Ottawa, co1: Canada, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Ottawa, co1: Canada, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Ottawa, co1: Canada, ci2: London, co2: England => pred_co2: England
# ci1: Ottawa, co1: Canada, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Ottawa, co1: Canada, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Ottawa, co1: Canada, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Paris, co1: France, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Paris, co1: France, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Paris, co1: France, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Paris, co1: France, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Paris, co1: France, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Paris, co1: France, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Paris, co1: France, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Paris, co1: France, ci2: Beijing, co2: China => pred_co2: China
# ci1: Paris, co1: France, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Paris, co1: France, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Paris, co1: France, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Paris, co1: France, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Paris, co1: France, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Paris, co1: France, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Paris, co1: France, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Paris, co1: France, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Paris, co1: France, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Paris, co1: France, ci2: London, co2: England => pred_co2: England
# ci1: Paris, co1: France, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Paris, co1: France, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Paris, co1: France, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Paris, co1: France, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Rome, co1: Italy, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Rome, co1: Italy, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Rome, co1: Italy, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Rome, co1: Italy, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Rome, co1: Italy, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Rome, co1: Italy, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Rome, co1: Italy, ci2: Beijing, co2: China => pred_co2: China
# ci1: Rome, co1: Italy, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Rome, co1: Italy, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Rome, co1: Italy, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Rome, co1: Italy, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Rome, co1: Italy, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Rome, co1: Italy, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Rome, co1: Italy, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Rome, co1: Italy, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Rome, co1: Italy, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Rome, co1: Italy, ci2: London, co2: England => pred_co2: Germany
# ci1: Rome, co1: Italy, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Rome, co1: Italy, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Rome, co1: Italy, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Rome, co1: Italy, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Rome, co1: Italy, ci2: Paris, co2: France => pred_co2: France
# ci1: Stockholm, co1: Sweden, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Stockholm, co1: Sweden, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Stockholm, co1: Sweden, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Stockholm, co1: Sweden, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Stockholm, co1: Sweden, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Stockholm, co1: Sweden, ci2: Beijing, co2: China => pred_co2: China
# ci1: Stockholm, co1: Sweden, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Stockholm, co1: Sweden, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Stockholm, co1: Sweden, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Stockholm, co1: Sweden, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Stockholm, co1: Sweden, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Stockholm, co1: Sweden, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Stockholm, co1: Sweden, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Stockholm, co1: Sweden, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Stockholm, co1: Sweden, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Stockholm, co1: Sweden, ci2: London, co2: England => pred_co2: England
# ci1: Stockholm, co1: Sweden, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Stockholm, co1: Sweden, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Stockholm, co1: Sweden, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Stockholm, co1: Sweden, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Stockholm, co1: Sweden, ci2: Paris, co2: France => pred_co2: France
# ci1: Stockholm, co1: Sweden, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Tehran, co1: Iran, ci2: Tokyo, co2: Japan => pred_co2: Japan
# ci1: Tehran, co1: Iran, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Tehran, co1: Iran, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Tehran, co1: Iran, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Tehran, co1: Iran, ci2: Beijing, co2: China => pred_co2: China
# ci1: Tehran, co1: Iran, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Tehran, co1: Iran, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Tehran, co1: Iran, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Tehran, co1: Iran, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Tehran, co1: Iran, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Tehran, co1: Iran, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Tehran, co1: Iran, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Tehran, co1: Iran, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Tehran, co1: Iran, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Tehran, co1: Iran, ci2: London, co2: England => pred_co2: England
# ci1: Tehran, co1: Iran, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Tehran, co1: Iran, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Tehran, co1: Iran, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Tehran, co1: Iran, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Tehran, co1: Iran, ci2: Paris, co2: France => pred_co2: France
# ci1: Tehran, co1: Iran, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Tehran, co1: Iran, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Tokyo, co1: Japan, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Tokyo, co1: Japan, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Tokyo, co1: Japan, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Tokyo, co1: Japan, ci2: Beijing, co2: China => pred_co2: China
# ci1: Tokyo, co1: Japan, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Tokyo, co1: Japan, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Tokyo, co1: Japan, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Tokyo, co1: Japan, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Tokyo, co1: Japan, ci2: Hanoi, co2: Vietnam => pred_co2: Vietnam
# ci1: Tokyo, co1: Japan, ci2: Havana, co2: Cuba => pred_co2: Cuba
# ci1: Tokyo, co1: Japan, ci2: Helsinki, co2: Finland => pred_co2: Finland
# ci1: Tokyo, co1: Japan, ci2: Islamabad, co2: Pakistan => pred_co2: Pakistan
# ci1: Tokyo, co1: Japan, ci2: Kabul, co2: Afghanistan => pred_co2: Afghanistan
# ci1: Tokyo, co1: Japan, ci2: London, co2: England => pred_co2: England
# ci1: Tokyo, co1: Japan, ci2: Madrid, co2: Spain => pred_co2: Spain
# ci1: Tokyo, co1: Japan, ci2: Moscow, co2: Russia => pred_co2: Russia
# ci1: Tokyo, co1: Japan, ci2: Oslo, co2: Norway => pred_co2: Norway
# ci1: Tokyo, co1: Japan, ci2: Ottawa, co2: Canada => pred_co2: Canada
# ci1: Tokyo, co1: Japan, ci2: Paris, co2: France => pred_co2: France
# ci1: Tokyo, co1: Japan, ci2: Rome, co2: Italy => pred_co2: Italy
# ci1: Tokyo, co1: Japan, ci2: Stockholm, co2: Sweden => pred_co2: Sweden
# ci1: Tokyo, co1: Japan, ci2: Tehran, co2: Iran => pred_co2: Iran
# ci1: Abuja, co1: Nigeria, ci2: Accra, co2: Ghana => pred_co2: Ghana
# ci1: Abuja, co1: Nigeria, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Abuja, co1: Nigeria, ci2: Amman, co2: Jordan => pred_co2: Egypt
# ci1: Abuja, co1: Nigeria, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Abuja, co1: Nigeria, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Abuja, co1: Nigeria, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Abuja, co1: Nigeria, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Abuja, co1: Nigeria, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Abuja, co1: Nigeria, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Abuja, co1: Nigeria, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Abuja, co1: Nigeria, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Abuja, co1: Nigeria, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Abuja, co1: Nigeria, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Abuja, co1: Nigeria, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Abuja, co1: Nigeria, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Abuja, co1: Nigeria, ci2: Beijing, co2: China => pred_co2: China
# ci1: Abuja, co1: Nigeria, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Abuja, co1: Nigeria, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Abuja, co1: Nigeria, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Abuja, co1: Nigeria, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Abuja, co1: Nigeria, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Abuja, co1: Nigeria, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Abuja, co1: Nigeria, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Abuja, co1: Nigeria, ci2: Brussels, co2: Belgium => pred_co2: Romania
# ci1: Abuja, co1: Nigeria, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Abuja, co1: Nigeria, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Abuja, co1: Nigeria, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Abuja, co1: Nigeria, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Abuja, co1: Nigeria, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Abuja, co1: Nigeria, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Abuja, co1: Nigeria, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Abuja, co1: Nigeria, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Abuja, co1: Nigeria, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Abuja, co1: Nigeria, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Abuja, co1: Nigeria, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Abuja, co1: Nigeria, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Abuja, co1: Nigeria, ci2: Doha, co2: Qatar => pred_co2: Qatar
# ci1: Abuja, co1: Nigeria, ci2: Dublin, co2: Ireland => pred_co2: Ireland
# ci1: Abuja, co1: Nigeria, ci2: Dushanbe, co2: Tajikistan => pred_co2: Tajikistan
# ci1: Accra, co1: Ghana, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Accra, co1: Ghana, ci2: Amman, co2: Jordan => pred_co2: Egypt
# ci1: Accra, co1: Ghana, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Accra, co1: Ghana, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Accra, co1: Ghana, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Accra, co1: Ghana, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Accra, co1: Ghana, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Accra, co1: Ghana, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Accra, co1: Ghana, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Accra, co1: Ghana, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Accra, co1: Ghana, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Accra, co1: Ghana, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Accra, co1: Ghana, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Accra, co1: Ghana, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Accra, co1: Ghana, ci2: Beijing, co2: China => pred_co2: China
# ci1: Accra, co1: Ghana, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Accra, co1: Ghana, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Accra, co1: Ghana, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Accra, co1: Ghana, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Accra, co1: Ghana, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Accra, co1: Ghana, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Accra, co1: Ghana, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Accra, co1: Ghana, ci2: Brussels, co2: Belgium => pred_co2: Romania
# ci1: Accra, co1: Ghana, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Accra, co1: Ghana, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Accra, co1: Ghana, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Accra, co1: Ghana, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Accra, co1: Ghana, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Accra, co1: Ghana, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Accra, co1: Ghana, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Accra, co1: Ghana, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Accra, co1: Ghana, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Accra, co1: Ghana, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Accra, co1: Ghana, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Accra, co1: Ghana, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Accra, co1: Ghana, ci2: Doha, co2: Qatar => pred_co2: Qatar
# ci1: Accra, co1: Ghana, ci2: Dublin, co2: Ireland => pred_co2: Ireland
# ci1: Accra, co1: Ghana, ci2: Dushanbe, co2: Tajikistan => pred_co2: Tajikistan
# ci1: Accra, co1: Ghana, ci2: Funafuti, co2: Tuvalu => pred_co2: Tuvalu
# ci1: Algiers, co1: Algeria, ci2: Amman, co2: Jordan => pred_co2: Egypt
# ci1: Algiers, co1: Algeria, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Algiers, co1: Algeria, ci2: Antananarivo, co2: Madagascar => pred_co2: Gabon
# ci1: Algiers, co1: Algeria, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Algiers, co1: Algeria, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Algiers, co1: Algeria, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Algiers, co1: Algeria, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Algiers, co1: Algeria, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Algiers, co1: Algeria, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Algiers, co1: Algeria, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Algiers, co1: Algeria, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Algiers, co1: Algeria, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Algiers, co1: Algeria, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Algiers, co1: Algeria, ci2: Beijing, co2: China => pred_co2: China
# ci1: Algiers, co1: Algeria, ci2: Beirut, co2: Lebanon => pred_co2: Syria
# ci1: Algiers, co1: Algeria, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Algiers, co1: Algeria, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Algiers, co1: Algeria, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Algiers, co1: Algeria, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Algiers, co1: Algeria, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Algiers, co1: Algeria, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Algiers, co1: Algeria, ci2: Brussels, co2: Belgium => pred_co2: Slovenia
# ci1: Algiers, co1: Algeria, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Algiers, co1: Algeria, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Algiers, co1: Algeria, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Algiers, co1: Algeria, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Algiers, co1: Algeria, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Algiers, co1: Algeria, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Algiers, co1: Algeria, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Algiers, co1: Algeria, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Algiers, co1: Algeria, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Algiers, co1: Algeria, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Algiers, co1: Algeria, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Algiers, co1: Algeria, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Algiers, co1: Algeria, ci2: Doha, co2: Qatar => pred_co2: Qatar
# ci1: Algiers, co1: Algeria, ci2: Dublin, co2: Ireland => pred_co2: Ireland
# ci1: Algiers, co1: Algeria, ci2: Dushanbe, co2: Tajikistan => pred_co2: Tajikistan
# ci1: Algiers, co1: Algeria, ci2: Funafuti, co2: Tuvalu => pred_co2: Slovenia
# ci1: Algiers, co1: Algeria, ci2: Gaborone, co2: Botswana => pred_co2: Botswana
# ci1: Amman, co1: Jordan, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Amman, co1: Jordan, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Amman, co1: Jordan, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Amman, co1: Jordan, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Amman, co1: Jordan, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Amman, co1: Jordan, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Amman, co1: Jordan, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Amman, co1: Jordan, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Amman, co1: Jordan, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Amman, co1: Jordan, ci2: Bamako, co2: Mali => pred_co2: Senegal
# ci1: Amman, co1: Jordan, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Amman, co1: Jordan, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Amman, co1: Jordan, ci2: Beijing, co2: China => pred_co2: China
# ci1: Amman, co1: Jordan, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Amman, co1: Jordan, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Amman, co1: Jordan, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Amman, co1: Jordan, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Amman, co1: Jordan, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Amman, co1: Jordan, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Amman, co1: Jordan, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Amman, co1: Jordan, ci2: Brussels, co2: Belgium => pred_co2: France
# ci1: Amman, co1: Jordan, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Amman, co1: Jordan, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Amman, co1: Jordan, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Amman, co1: Jordan, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Amman, co1: Jordan, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Amman, co1: Jordan, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Amman, co1: Jordan, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Amman, co1: Jordan, ci2: Conakry, co2: Guinea => pred_co2: Libreville
# ci1: Amman, co1: Jordan, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Amman, co1: Jordan, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Amman, co1: Jordan, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Amman, co1: Jordan, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Amman, co1: Jordan, ci2: Doha, co2: Qatar => pred_co2: Qatar
# ci1: Amman, co1: Jordan, ci2: Dublin, co2: Ireland => pred_co2: Ireland
# ci1: Amman, co1: Jordan, ci2: Dushanbe, co2: Tajikistan => pred_co2: Tajikistan
# ...
# ci1: Vientiane, co1: Laos, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Vientiane, co1: Laos, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Vientiane, co1: Laos, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Vientiane, co1: Laos, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Vientiane, co1: Laos, ci2: Brussels, co2: Belgium => pred_co2: Belgium
# ci1: Vientiane, co1: Laos, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Vientiane, co1: Laos, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Vientiane, co1: Laos, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Vientiane, co1: Laos, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Vientiane, co1: Laos, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Vientiane, co1: Laos, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Vientiane, co1: Laos, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Vientiane, co1: Laos, ci2: Conakry, co2: Guinea => pred_co2: Burundi
# ci1: Vientiane, co1: Laos, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Vilnius, co1: Lithuania, ci2: Warsaw, co2: Poland => pred_co2: Poland
# ci1: Vilnius, co1: Lithuania, ci2: Windhoek, co2: Namibia => pred_co2: Namibia
# ci1: Vilnius, co1: Lithuania, ci2: Yerevan, co2: Armenia => pred_co2: Armenia
# ci1: Vilnius, co1: Lithuania, ci2: Zagreb, co2: Croatia => pred_co2: Croatia
# ci1: Vilnius, co1: Lithuania, ci2: Abuja, co2: Nigeria => pred_co2: Nigeria
# ci1: Vilnius, co1: Lithuania, ci2: Accra, co2: Ghana => pred_co2: Ghana
# ci1: Vilnius, co1: Lithuania, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Vilnius, co1: Lithuania, ci2: Amman, co2: Jordan => pred_co2: Oman
# ci1: Vilnius, co1: Lithuania, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Vilnius, co1: Lithuania, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Vilnius, co1: Lithuania, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Vilnius, co1: Lithuania, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Vilnius, co1: Lithuania, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Vilnius, co1: Lithuania, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Vilnius, co1: Lithuania, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Vilnius, co1: Lithuania, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Vilnius, co1: Lithuania, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Vilnius, co1: Lithuania, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Vilnius, co1: Lithuania, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Vilnius, co1: Lithuania, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Vilnius, co1: Lithuania, ci2: Beijing, co2: China => pred_co2: China
# ci1: Vilnius, co1: Lithuania, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Vilnius, co1: Lithuania, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Vilnius, co1: Lithuania, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Vilnius, co1: Lithuania, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Vilnius, co1: Lithuania, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Vilnius, co1: Lithuania, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Vilnius, co1: Lithuania, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Vilnius, co1: Lithuania, ci2: Brussels, co2: Belgium => pred_co2: Belgium
# ci1: Vilnius, co1: Lithuania, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Vilnius, co1: Lithuania, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Vilnius, co1: Lithuania, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Vilnius, co1: Lithuania, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Vilnius, co1: Lithuania, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Vilnius, co1: Lithuania, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Vilnius, co1: Lithuania, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Vilnius, co1: Lithuania, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Vilnius, co1: Lithuania, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Vilnius, co1: Lithuania, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Warsaw, co1: Poland, ci2: Windhoek, co2: Namibia => pred_co2: Namibia
# ci1: Warsaw, co1: Poland, ci2: Yerevan, co2: Armenia => pred_co2: Armenia
# ci1: Warsaw, co1: Poland, ci2: Zagreb, co2: Croatia => pred_co2: Croatia
# ci1: Warsaw, co1: Poland, ci2: Abuja, co2: Nigeria => pred_co2: Nigeria
# ci1: Warsaw, co1: Poland, ci2: Accra, co2: Ghana => pred_co2: Ghana
# ci1: Warsaw, co1: Poland, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Warsaw, co1: Poland, ci2: Amman, co2: Jordan => pred_co2: Syria
# ci1: Warsaw, co1: Poland, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Warsaw, co1: Poland, ci2: Antananarivo, co2: Madagascar => pred_co2: Conakry
# ci1: Warsaw, co1: Poland, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Warsaw, co1: Poland, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Warsaw, co1: Poland, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Warsaw, co1: Poland, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Warsaw, co1: Poland, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Warsaw, co1: Poland, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Warsaw, co1: Poland, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Warsaw, co1: Poland, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Warsaw, co1: Poland, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Warsaw, co1: Poland, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Warsaw, co1: Poland, ci2: Beijing, co2: China => pred_co2: China
# ci1: Warsaw, co1: Poland, ci2: Beirut, co2: Lebanon => pred_co2: Syria
# ci1: Warsaw, co1: Poland, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Warsaw, co1: Poland, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Warsaw, co1: Poland, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Warsaw, co1: Poland, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Warsaw, co1: Poland, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Warsaw, co1: Poland, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Warsaw, co1: Poland, ci2: Brussels, co2: Belgium => pred_co2: Belgium
# ci1: Warsaw, co1: Poland, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Warsaw, co1: Poland, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Warsaw, co1: Poland, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Warsaw, co1: Poland, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Warsaw, co1: Poland, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Warsaw, co1: Poland, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Warsaw, co1: Poland, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Warsaw, co1: Poland, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Warsaw, co1: Poland, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Warsaw, co1: Poland, ci2: Dakar, co2: Senegal => pred_co2: Mauritania
# ci1: Warsaw, co1: Poland, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Windhoek, co1: Namibia, ci2: Yerevan, co2: Armenia => pred_co2: Armenia
# ci1: Windhoek, co1: Namibia, ci2: Zagreb, co2: Croatia => pred_co2: Croatia
# ci1: Windhoek, co1: Namibia, ci2: Abuja, co2: Nigeria => pred_co2: Nigeria
# ci1: Windhoek, co1: Namibia, ci2: Accra, co2: Ghana => pred_co2: Ghana
# ci1: Windhoek, co1: Namibia, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Windhoek, co1: Namibia, ci2: Amman, co2: Jordan => pred_co2: Morocco
# ci1: Windhoek, co1: Namibia, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Windhoek, co1: Namibia, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Windhoek, co1: Namibia, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Windhoek, co1: Namibia, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Windhoek, co1: Namibia, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Windhoek, co1: Namibia, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Windhoek, co1: Namibia, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Windhoek, co1: Namibia, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Windhoek, co1: Namibia, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Windhoek, co1: Namibia, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Windhoek, co1: Namibia, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Windhoek, co1: Namibia, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Windhoek, co1: Namibia, ci2: Beijing, co2: China => pred_co2: China
# ci1: Windhoek, co1: Namibia, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Windhoek, co1: Namibia, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Windhoek, co1: Namibia, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Windhoek, co1: Namibia, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Windhoek, co1: Namibia, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Windhoek, co1: Namibia, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Windhoek, co1: Namibia, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Windhoek, co1: Namibia, ci2: Brussels, co2: Belgium => pred_co2: France
# ci1: Windhoek, co1: Namibia, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Windhoek, co1: Namibia, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Windhoek, co1: Namibia, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Windhoek, co1: Namibia, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Windhoek, co1: Namibia, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Windhoek, co1: Namibia, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Windhoek, co1: Namibia, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Windhoek, co1: Namibia, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Windhoek, co1: Namibia, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Windhoek, co1: Namibia, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Windhoek, co1: Namibia, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Windhoek, co1: Namibia, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Yerevan, co1: Armenia, ci2: Zagreb, co2: Croatia => pred_co2: Croatia
# ci1: Yerevan, co1: Armenia, ci2: Abuja, co2: Nigeria => pred_co2: Nigeria
# ci1: Yerevan, co1: Armenia, ci2: Accra, co2: Ghana => pred_co2: Ghana
# ci1: Yerevan, co1: Armenia, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Yerevan, co1: Armenia, ci2: Amman, co2: Jordan => pred_co2: Jordan
# ci1: Yerevan, co1: Armenia, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Yerevan, co1: Armenia, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Yerevan, co1: Armenia, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Yerevan, co1: Armenia, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Yerevan, co1: Armenia, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Yerevan, co1: Armenia, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Yerevan, co1: Armenia, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Yerevan, co1: Armenia, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Yerevan, co1: Armenia, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Yerevan, co1: Armenia, ci2: Bamako, co2: Mali => pred_co2: Senegal
# ci1: Yerevan, co1: Armenia, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Yerevan, co1: Armenia, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Yerevan, co1: Armenia, ci2: Beijing, co2: China => pred_co2: China
# ci1: Yerevan, co1: Armenia, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Yerevan, co1: Armenia, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Yerevan, co1: Armenia, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Yerevan, co1: Armenia, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Yerevan, co1: Armenia, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Yerevan, co1: Armenia, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Yerevan, co1: Armenia, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Yerevan, co1: Armenia, ci2: Brussels, co2: Belgium => pred_co2: Turkey
# ci1: Yerevan, co1: Armenia, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Yerevan, co1: Armenia, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Yerevan, co1: Armenia, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Yerevan, co1: Armenia, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Yerevan, co1: Armenia, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Yerevan, co1: Armenia, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Yerevan, co1: Armenia, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Yerevan, co1: Armenia, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Yerevan, co1: Armenia, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Yerevan, co1: Armenia, ci2: Dakar, co2: Senegal => pred_co2: Mauritania
# ci1: Yerevan, co1: Armenia, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Yerevan, co1: Armenia, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Yerevan, co1: Armenia, ci2: Doha, co2: Qatar => pred_co2: Qatar
# ci1: Zagreb, co1: Croatia, ci2: Abuja, co2: Nigeria => pred_co2: Nigeria
# ci1: Zagreb, co1: Croatia, ci2: Accra, co2: Ghana => pred_co2: Ghana
# ci1: Zagreb, co1: Croatia, ci2: Algiers, co2: Algeria => pred_co2: Algeria
# ci1: Zagreb, co1: Croatia, ci2: Amman, co2: Jordan => pred_co2: Morocco
# ci1: Zagreb, co1: Croatia, ci2: Ankara, co2: Turkey => pred_co2: Turkey
# ci1: Zagreb, co1: Croatia, ci2: Antananarivo, co2: Madagascar => pred_co2: Madagascar
# ci1: Zagreb, co1: Croatia, ci2: Apia, co2: Samoa => pred_co2: Samoa
# ci1: Zagreb, co1: Croatia, ci2: Ashgabat, co2: Turkmenistan => pred_co2: Turkmenistan
# ci1: Zagreb, co1: Croatia, ci2: Asmara, co2: Eritrea => pred_co2: Eritrea
# ci1: Zagreb, co1: Croatia, ci2: Astana, co2: Kazakhstan => pred_co2: Kazakhstan
# ci1: Zagreb, co1: Croatia, ci2: Athens, co2: Greece => pred_co2: Greece
# ci1: Zagreb, co1: Croatia, ci2: Baghdad, co2: Iraq => pred_co2: Iraq
# ci1: Zagreb, co1: Croatia, ci2: Baku, co2: Azerbaijan => pred_co2: Azerbaijan
# ci1: Zagreb, co1: Croatia, ci2: Bamako, co2: Mali => pred_co2: Mali
# ci1: Zagreb, co1: Croatia, ci2: Bangkok, co2: Thailand => pred_co2: Thailand
# ci1: Zagreb, co1: Croatia, ci2: Banjul, co2: Gambia => pred_co2: Gambia
# ci1: Zagreb, co1: Croatia, ci2: Beijing, co2: China => pred_co2: China
# ci1: Zagreb, co1: Croatia, ci2: Beirut, co2: Lebanon => pred_co2: Lebanon
# ci1: Zagreb, co1: Croatia, ci2: Belgrade, co2: Serbia => pred_co2: Serbia
# ci1: Zagreb, co1: Croatia, ci2: Belmopan, co2: Belize => pred_co2: Belize
# ci1: Zagreb, co1: Croatia, ci2: Berlin, co2: Germany => pred_co2: Germany
# ci1: Zagreb, co1: Croatia, ci2: Bern, co2: Switzerland => pred_co2: Switzerland
# ci1: Zagreb, co1: Croatia, ci2: Bishkek, co2: Kyrgyzstan => pred_co2: Kyrgyzstan
# ci1: Zagreb, co1: Croatia, ci2: Bratislava, co2: Slovakia => pred_co2: Slovakia
# ci1: Zagreb, co1: Croatia, ci2: Brussels, co2: Belgium => pred_co2: France
# ci1: Zagreb, co1: Croatia, ci2: Bucharest, co2: Romania => pred_co2: Romania
# ci1: Zagreb, co1: Croatia, ci2: Budapest, co2: Hungary => pred_co2: Hungary
# ci1: Zagreb, co1: Croatia, ci2: Bujumbura, co2: Burundi => pred_co2: Burundi
# ci1: Zagreb, co1: Croatia, ci2: Cairo, co2: Egypt => pred_co2: Egypt
# ci1: Zagreb, co1: Croatia, ci2: Canberra, co2: Australia => pred_co2: Australia
# ci1: Zagreb, co1: Croatia, ci2: Caracas, co2: Venezuela => pred_co2: Venezuela
# ci1: Zagreb, co1: Croatia, ci2: Chisinau, co2: Moldova => pred_co2: Moldova
# ci1: Zagreb, co1: Croatia, ci2: Conakry, co2: Guinea => pred_co2: Guinea
# ci1: Zagreb, co1: Croatia, ci2: Copenhagen, co2: Denmark => pred_co2: Denmark
# ci1: Zagreb, co1: Croatia, ci2: Dakar, co2: Senegal => pred_co2: Senegal
# ci1: Zagreb, co1: Croatia, ci2: Damascus, co2: Syria => pred_co2: Syria
# ci1: Zagreb, co1: Croatia, ci2: Dhaka, co2: Bangladesh => pred_co2: Bangladesh
# ci1: Zagreb, co1: Croatia, ci2: Doha, co2: Qatar => pred_co2: Qatar
# ci1: Zagreb, co1: Croatia, ci2: Dublin, co2: Ireland => pred_co2: Ireland
# Accuracy is 0.92

# %% [markdown]
# **Expected Output:**
#
# $\approx$ 0.92

# %% [markdown]
# # 3.0 Plotting the vectors using PCA
#
# Now you will explore the distance between word vectors after reducing their dimension.
# The technique we will employ is known as
# [*principal component analysis* (PCA)](https://en.wikipedia.org/wiki/Principal_component_analysis).
# As we saw, we are working in a 300-dimensional space in this case.
# Although from a computational perspective we were able to perform a good job,
# it is impossible to visualize results in such high dimensional spaces.
#
# You can think of PCA as a method that projects our vectors in a space of reduced
# dimension, while keeping the maximum information about the original vectors in
# their reduced counterparts. In this case, by *maximum infomation* we mean that the
# Euclidean distance between the original vectors and their projected siblings is
# minimal. Hence vectors that were originally close in the embeddings dictionary,
# will produce lower dimensional vectors that are still close to each other.
#
# You will see that when you map out the words, similar words will be clustered
# next to each other. For example, the words 'sad', 'happy', 'joyful' all describe
# emotion and are supposed to be near each other when plotted.
# The words: 'oil', 'gas', and 'petroleum' all describe natural resources.
# Words like 'city', 'village', 'town' could be seen as synonyms and describe a
# similar thing.
#
# Before plotting the words, you need to first be able to reduce each word vector
# with PCA into 2 dimensions and then plot it. The steps to compute PCA are as follows:
#
# 1. Mean normalize the data
# 2. Compute the covariance matrix of your data ($\Sigma$).
# 3. Compute the eigenvectors and the eigenvalues of your covariance matrix
# 4. Multiply the first K eigenvectors by your normalized data. The transformation should look something as follows:
#
# <img src = 'word_embf.jpg' width="width" height="height" style="width:800px;height:200px;"/>

# %% [markdown]
# **Instructions**:
#
# You will write a program that takes in a data set where each row corresponds to a word vector.
# * The word vectors are of dimension 300.
# * Use PCA to change the 300 dimensions to `n_components` dimensions.
# * The new matrix should be of dimension `m, n_componentns`.
#
# * First de-mean the data
# * Get the eigenvalues using `linalg.eigh`.  Use `eigh` rather than `eig` since R is symmetric.  The performance gain when using `eigh` instead of `eig` is substantial.
# * Sort the eigenvectors and eigenvalues by decreasing order of the eigenvalues.
# * Get a subset of the eigenvectors (choose how many principle components you want to use using `n_components`).
# * Return the new transformation of the data by multiplying the eigenvectors with the original data.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.mean.html" > numpy.mean(a,axis=None) </a> : If you set <code>axis = 0</code>, you take the mean for each column.  If you set <code>axis = 1</code>, you take the mean for each row.  Remember that each row is a word vector, and the number of columns are the number of dimensions in a word vector. </li>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.cov.html" > numpy.cov(m, rowvar=True) </a>. This calculates the covariance matrix.  By default <code>rowvar</code> is <code>True</code>.  From the documentation: "If rowvar is True (default), then each row represents a variable, with observations in the columns."  In our case, each row is a word vector observation, and each column is a feature (variable). </li>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.linalg.eigh.html" > numpy.linalg.eigh(a, UPLO='L') </a> </li>
#     <li>Use <a href="https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html" > numpy.argsort </a> sorts the values in an array from smallest to largest, then returns the indices from this sort. </li>
#     <li>In order to reverse the order of a list, you can use: <code>x[::-1]</code>.</li>
#     <li>To apply the sorted indices to eigenvalues, you can use this format <code>x[indices_sorted]</code>.</li>
#     <li>When applying the sorted indices to eigen vectors, note that each column represents an eigenvector.  In order to preserve the rows but sort on the columns, you can use this format <code>x[:,indices_sorted]</code></li>
#     <li>To transform the data using a subset of the most relevant principle components, take the matrix multiplication of the eigenvectors with the original data.  </li>
#     <li>The data is of shape <code>(n_observations, n_features)</code>.  </li>
#     <li>The subset of eigenvectors are in a matrix of shape <code>(n_features, n_components)</code>.</li>
#     <li>To multiply these together, take the transposes of both the eigenvectors <code>(n_components, n_features)</code> and the data (n_features, n_observations).</li>
#     <li>The product of these two has dimensions <code>(n_components,n_observations)</code>.  Take its transpose to get the shape <code>(n_observations, n_components)</code>.</li>
# </ul>
# </p>

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def compute_pca(X, n_components=2):
    """
    Input:
        X: of dimension (m,n) where each row corresponds to a word vector
        n_components: Number of components you want to keep.
    Output:
        X_reduced: data transformed in 2 dims/columns + regenerated original data
    """

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # mean center the data
    # NOTE: Read for mean centered vs standardization as well as covariance & correlation
    # Discussion thread subject: mean center the data
    # https://stats.stackexchange.com/questions/53/pca-on-correlation-or-covariance
    
    X_demeaned = X - np.mean(X, axis=0)
    #print(X_demeaned.shape)

    # https://stats.stackexchange.com/questions/36254/mean-centering-for-pca-in-a-2d-array-across-rows-or-cols
    # calculate the covariance matrix
    covariance_matrix = np.cov(X_demeaned, rowvar=False)
    #print(covariance_matrix.shape)
    
    # calculate eigenvectors & eigenvalues of the covariance matrix
    eigen_vals, eigen_vecs = np.linalg.eigh(covariance_matrix)
    eigen_vals_len = eigen_vals.shape[0]
    #print(f'eig_vals.shape: {eigen_vals.shape}, eigen_vecs.shape: {eigen_vecs.shape}')
    #print(eigen_vals)
    #print(eigen_vecs)

    # SORTING not needed as eigh returns in asc order of eig values
    # sort eigenvalue in increasing order (get the indices from the sort)
    idx_sorted = np.argsort(eigen_vals, axis=0).reshape(1, eigen_vals_len)
    #print(idx_sorted.shape)
    #print(idx_sorted)
    
    # reverse the order so that it's from highest to lowest.
    idx_sorted_decreasing = np.fliplr(idx_sorted).squeeze()
    #print(idx_sorted_decreasing)

    # sort the eigen values by idx_sorted_decreasing
    eigen_vals_sorted = eigen_vals[idx_sorted_decreasing]
    #print(eigen_vals_sorted.shape)

    # sort eigenvectors using the idx_sorted_decreasing indices
    eigen_vecs_sorted = eigen_vecs[:, idx_sorted_decreasing]
    #print(eigen_vecs_sorted)

    # select the first n eigenvectors (n is desired dimension
    # of rescaled data array, or dims_rescaled_data)
    eigen_vecs_subset = eigen_vecs_sorted[:, 0:n_components]
    #print(eigen_vecs_subset.shape)
    #print(eigen_vecs_subset)
    
    # transform the data by multiplying the transpose of the eigenvectors 
    # with the transpose of the de-meaned data
    # Then take the transpose of that product.
    X_reduced = np.dot(X_demeaned, eigen_vecs_subset)

    ### END CODE HERE ###

    return X_reduced

# %%
# Testing your function
np.random.seed(1)
X = np.random.rand(3, 10)
X_reduced = compute_pca(X, n_components=2)
print("Your original matrix was " + str(X.shape) + " and it became:")
print(X_reduced)
# Out:
# Your original matrix was (3, 10) and it became:
# [[ 0.43437323  0.49820384]
#  [ 0.42077249 -0.50351448]
#  [-0.85514571  0.00531064]]

# %% [markdown]
# **Expected Output:**
#
# Your original matrix was: (3,10) and it became:
#
# <table>
#     <tr>
#         <td>
#            0.43437323
#             </td>
#                 <td>
#             0.49820384
#             </td>
#     </tr>
#     <tr>
#         <td>
#             0.42077249
#             </td>
#                 <td>
#            -0.50351448
#             </td>
#     </tr>
#     <tr>
#         <td>
#             -0.85514571
#             </td>
#                 <td>
#            0.00531064
#             </td>
#     </tr>
# </table>
#
# Now you will use your pca function to plot a few words we have chosen for you.
# You will see that similar words tend to be clustered near each other.
# Sometimes, even antonyms tend to be clustered near each other. Antonyms
# describe the same thing but just tend to be on the other end of the scale
# They are usually found in the same location of a sentence,
# have the same parts of speech, and thus when
# learning the word vectors, you end up getting similar weights. In the next week
# we will go over how you learn them, but for now let's just enjoy using them.
#
# **Instructions:** Run the cell below.

# %%
words = ['oil', 'gas', 'happy', 'sad', 'city', 'town',
         'village', 'country', 'continent', 'petroleum', 'joyful']

# given a list of words and the embeddings, it returns a matrix with all the embeddings
X = get_vectors(word_embeddings, words)

print('You have 11 words each of 300 dimensions thus X.shape is:', X.shape)
# Out:
# You have 11 words each of 300 dimensions thus X.shape is: (11, 300)

# %%
# We have done the plotting for you. Just run this cell.
result = compute_pca(X, 2)
plt.scatter(result[:, 0], result[:, 1])
for i, word in enumerate(words):
    plt.annotate(word, xy=(result[i, 0] - 0.05, result[i, 1] + 0.1))

plt.show()

# %% [markdown]
# **What do you notice?**
#
# The word vectors for 'gas', 'oil' and 'petroleum' appear related to each other,
# because their vectors are close to each other.  Similarly, 'sad', 'joyful'
# and 'happy' all express emotions, and are also near each other.
